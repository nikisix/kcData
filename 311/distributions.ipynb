# %%
# -*- coding: utf-8 -*-
# <nbformat>3.0</nbformat>
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import animation

import pymc as pm
import pandas as pd
import numpy as np
# from pylab import *
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
# from JSAnimation import IPython_display


#d = pd.read_csv('data/311data') #full set
d = pd.read_csv('data/311data', nrows=1000) #limit to 1k rows for testing
d = pd.DataFrame(d, columns=['creation_date', 'closed_date', 'latitude', 'longitude', 'request_type'])
#d.sort(columns=['closed_date'], ascending=True, inplace=True) #do this after filtering to save on cycles

#-1 is the value that find returns if it doesn't find the string
#Filter the Dataset. Remove all rows without 'Water' in their request_type
data = pd.DataFrame
i = 0
for index, row in d.iterrows():
     if(\
       ( str.upper(row['request_type']).find('WATER') != -1 ) and\
       ( row['longitude']  !=0 ) and\
       ( row['latitude' ]  !=0 ) ):            
            row_frame = pd.DataFrame([{'creation_date':row.creation_date, 'closed_date':row.closed_date, 'longitude':row.longitude, 'latitude':row.latitude, 'request_type':row.request_type }])
            if i == 0: 
                data = row_frame
                i+=1
            else: 
                data = data.append(row_frame)

del d #relax d's memory usage
data.sort(columns=['closed_date'], ascending=True, inplace=True)
dt_index = pd.DatetimeIndex(pd.to_datetime(data.closed_date))
data = data.set_index(dt_index)
#data['2009-12-31':'2010-1-31'] #works :)

# %%
#accessing
#data['2009-12-31T00:00:00':'2010-1-31T00:00:00']
#data['2009-12-31':'2010-1-31']
#data.closed_date.where(d2.closed_date < '2010-01-28T00:00:00')
#data['2009-12-31']['request_type'].count()

dt_index = pd.to_datetime(data.closed_date)
d2 = data.set_index(dt_index)
d3 = data.set_index(pd.DatetimeIndex(data.closed_date))
print d3.index
print d2.index
print data.index
del d2, d3
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-12-31, ..., NaT]
# Length: 46, Freq: None, Timezone: None
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-12-31, ..., NaT]
# Length: 46, Freq: None, Timezone: None
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-12-31, ..., NaT]
# Length: 46, Freq: None, Timezone: None

# %%
#xlim=(38.75, 39.5), latitudes
#ylim=(-95, -94)),   longitudes
#d31 = pd.to_datetime('2009-12-31T00:00:00')
#print [d31 + pd.DateOffset(n=i) for i in range(1,10)]
LAT_BEGIN = 38.75
LAT_END   = 39.5
LON_BEGIN = -96
LON_END   = -95
N_STEPS   = 3
lat_steps = linspace(LAT_BEGIN, LAT_END, N_STEPS)
lon_steps = linspace(LON_BEGIN, LON_END, N_STEPS)
"""
the grid variable represents quadrants of latitude and longitude
i.e. a 3x3 grid of squares at every point in time
-95.0 38.75 - grid[0]
-95.5 38.75 - grid[1]
-96.0 38.75 - ...
-95.0 39.125
-95.5 39.125
-96.0 39.125
-95.0 39.5
-95.5 39.5
-96.0 39.5 - grid[8]
"""
#returns the grid indicies for a particular geo point
#N_STEPS-1 => one to compensate the +1 lookahead
def in_square(lat, lon, lat_steps, lon_steps):
    if(lon < lon_steps[0]):           lon_index = 0
    elif(lon_steps[N_STEPS-1] < lon): lon_index = N_STEPS-1
    else:
        for x in range(0, N_STEPS - 1):
            if(lon_steps[x] < lon < lon_steps[x+1]):  lon_index = x
   
    if(lat < lat_steps[0]):           lat_index = 0
    elif(lat_steps[N_STEPS-1] < lat): lat_index = N_STEPS-1            
    else:
        for y in range(0, N_STEPS - 1): 
            if(lat_steps[y] < lat < lat_steps[y+1]):  lat_index = y

    return lat_index, lon_index

"""grid_split [] [] / [] [] / [] []
input:  lats - list of latitudes on day d
        lons - list of longitudes on day d
        
output: count for each square
[1] [3] / [2] [1] / [0] [1]
"""
def grid_split_2d(lats, lons, lat_steps, lon_steps, day_data):
    grid = zeros((len(lat_steps), len(lon_steps)))
    for i, row in day_data.iterrows():
        lat_index, lon_index = in_square(row.latitude, row.longitude, lat_steps, lon_steps)
        grid[lat_index, lon_index] += 1
    return grid

"""returns a 1d grid in array form"""
def grid_split_1d(lats, lons, lat_steps, lon_steps, day_data):
    grid = zeros((len(lat_steps) * len(lon_steps)))
    for i, row in day_data.iterrows():
        lat_index, lon_index = in_square(row.latitude, row.longitude, lat_steps, lon_steps)
        grid[(N_STEPS*lat_index) + lon_index] += 1 #could also be len(lon_steps)*lat_index
    return grid

# %%
#data[str(pd.to_datetime('2009-12-31 00:00:00'))]
#data['2009-12-31 00:00:00']

#grid2d.get(pd.Timestamp('2012-12-31 00:00:00'))
#grid2d.get(pd.Timestamp('2012-12-31'))

grid1d = dict()
for date_index in data.index:    
    if (pd.isnull(date_index)): break #last few rows are always NaT (Not a Time) :(
    day_data = data[str(date_index)]
    grid1d[date_index] = grid_split_1d(day_data.latitude, day_data.longitude, lat_steps, lon_steps, day_data)

# %%
#pandas messes up the date format when it saves an index 
#date_index.date() removes the timezone info: 2009-12-31 00:00:00 -> 2009-12-31
#date_index = '2009-12-31'
grid2d = dict()
for date_index in data.index:    
    if (pd.isnull(date_index)): break #last few rows are always NaT (Not a Time) :(
    day_data = data[str(date_index)]
    grid2d[date_index] = grid_split_2d(day_data.latitude, day_data.longitude, lat_steps, lon_steps, day_data)

# %%
#grid2d

# %%
#grid1d

# %% [raw]
# help (pm.Dirichlet)
#  |      :Parameters:
#  |        x : (n, k-1) array
#  |          Array of shape (n, k-1) where `n` is the number of samples
#  |          and `k` the dimension.
#  |          :math:`0 < x_i < 1`,  :math:`\sum_{i=1}^{k-1} x_i < 1`
#  |        theta : array
#  |          An (n,k) or (1,k) array > 0.

# %%
dirich = pm.Dirichlet('theta', theta=[1, 1, 1])
print dirich.random()
# Out:
# [ 0.08910688  0.15590563]

# %% [raw]
# help(pm.Multinomial)
# class Multinomial(pymc.PyMCObjects.Stochastic)
#  |  M = Multinomial(name, n, p, trace=True, value=None,
#  |     rseed=False, observed=False, cache_depth=2, plot=None])
#  |
#  |  A multinomial random variable. Parents are p, minval, step.
#  |
#  |  If parent p is Dirichlet and has length k-1, an implicit k'th
#  |  category is assumed to exist with associated probability 1-sum(p.value).
#  |
#  |  Otherwise parent p's value should sum to 1.

# %%
multi = pm.Multinomial('multi', n=3, p=dirich)
print multi.random()
# Out:
# [0 1 2]

# %%
#np.shape(grid1d.values())
#np.reshape(grid1d.values(), (1, 162))[0]
grid1d.values()
# Out:
# [array([ 0.,  0.,  4.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  2.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  4.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  6.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  2.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  6.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  3.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  3.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  2.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.])]

# %%
#uniform prior (all ones), either this or discrete_uniform
#unif = pm.DiscreteUniform('unif', 0, 1, size=[1,N_STEPS**2] )
#alpha = unif.random()
alpha = ones(N_STEPS**2)
dirich = pm.Dirichlet('dirich', theta = alpha)


#set n equal to the average of the daily count data
total = sum(data.groupby('closed_date').count())
num_elements = len(data.groupby('closed_date'))
avg_calls_per_day = total[0] / num_elements

#set n = to poison centered on n
poisson1 = pm.Poisson('poisson', mu = avg_calls_per_day)

#multi = pm.Multinomial('multi', n=poisson1, p=dirich, value=grid1d.values()[0], observed=True)
multi = pm.Multinomial('multi', n=poisson1, p=dirich, value=grid2d.values(), observed=True)
model = pm.Model([multi, dirich])
# Out:
# ---------------------------------------------------------------------------
# ZeroProbability                           Traceback (most recent call last)
# <ipython-input-420-7551011e4c2a> in <module>()
#      15
#      16 #multi = pm.Multinomial('multi', n=poisson1, p=dirich, value=grid1d.values()[0], observed=True)
# ---> 17 multi = pm.Multinomial('multi', n=poisson1, p=dirich, value=grid2d.values(), observed=True)
#      18 model = pm.Model([multi, dirich])
#
# /usr/local/lib/python2.7/dist-packages/pymc/distributions.pyc in __init__(self, name, n, p, trace, value, rseed, observed, cache_depth, plot, verbose, **kwds)
#    3043                                 rseed=rseed, observed=observed,
#    3044                                 cache_depth=cache_depth, plot=plot,
# -> 3045                                 verbose=verbose, **kwds)
#    3046         else:
#    3047             Stochastic.__init__(self, logp=valuewrapper(multinomial_like),
#
# /usr/local/lib/python2.7/dist-packages/pymc/PyMCObjects.pyc in __init__(self, logp, doc, name, parents, random, trace, value, dtype, rseed, observed, cache_depth, plot, verbose, isdata, check_logp, logp_partial_gradients)
#     757         if check_logp:
#     758             # Check initial value
# --> 759             if not isinstance(self.logp, float):
#     760                 raise ValueError(
#     761                     "Stochastic " +
#
# /usr/local/lib/python2.7/dist-packages/pymc/PyMCObjects.pyc in get_logp(self)
#     914                     (self._value, self._parents.value))
#     915             else:
# --> 916                 raise ZeroProbability(self.errmsg)
#     917
#     918         return logp
#
# ZeroProbability: Stochastic multi's value is outside its support,
#  or it forbids its parents' current values.

# %%
alpha = ones((N_STEPS**2))
alpha
#dirich = pm.Dirichlet('dirich', theta = alpha)
# Out:
# array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.])

# %%
help(pm.PyMCObjects.Stochastic)
# Out:
# Help on class Stochastic in module pymc.PyMCObjects:
#
# class Stochastic(pymc.Node.StochasticBase)
#  |  A variable whose value is not determined by the values of its parents.
#  |
#  |
#  |  Decorator instantiation:
#  |
#  |  @stoch(trace=True)
#  |  def X(value = 0., mu = B, tau = C):
#  |      return Normal_like(value, mu, tau)
#  |
#  |  @stoch(trace=True)
#  |  def X(value=0., mu=B, tau=C):
#  |
#  |      def logp(value, mu, tau):
#  |          return Normal_like(value, mu, tau)
#  |
#  |      def random(mu, tau):
#  |          return Normal_r(mu, tau)
#  |
#  |      rseed = 1.
#  |
#  |
#  |  Direct instantiation:
#  |
#  |
#  |
#  |  - logp : function
#  |          The function that computes the variable's log-probability from
#  |          its value and the values of its parents.
#  |
#  |  - doc : string
#  |          The docstring for this variable.
#  |
#  |  - name : string
#  |          The name of this variable.
#  |
#  |  - parents: dict
#  |          A dictionary containing the parents of this variable.
#  |
#  |  - random (optional) : function
#  |          A function that draws a new value for this
#  |          variable given its parents' values.
#  |
#  |  - trace (optional) : boolean
#  |          A boolean indicating whether this variable's value
#  |          should be traced (in MCMC).
#  |
#  |  - value (optional) : number or array
#  |          An initial value for this variable
#  |
#  |  - dtype (optional) : type
#  |          A type for this variable.
#  |
#  |  - rseed (optional) : integer or rseed
#  |          A seed for this variable's rng. Either value or rseed must
#  |          be given.
#  |
#  |  - observed (optional) :  boolean
#  |          A flag indicating whether this variable is data; whether
#  |          its value is known.
#  |
#  |  - cache_depth (optional) : integer
#  |          An integer indicating how many of this variable's
#  |          log-probability computations should be 'memoized'.
#  |
#  |  - plot (optional) : boolean
#  |          A flag indicating whether this variable is to be plotted.
#  |
#  |  - verbose (optional) : integer
#  |          Level of output verbosity: 0=none, 1=low, 2=medium, 3=high
#  |
#  |
#  |  Externally-accessible attribute:
#  |
#  |  - value: any class
#  |        Returns this variable's current value.
#  |
#  |  - logp: float
#  |        Returns the variable's log-probability given its value and its
#  |        parents' values. Skips computation if possible.
#  |
#  |  last_value: any class
#  |        Returns this variable's last value. Useful for rejecting
#  |        Metropolis-Hastings jumps. See touch() and the warning below.
#  |
#  |  Externally-accessible methods:
#  |
#  |  random():   Draws a new value for this variable from its distribution and
#  |              returns it.
#  |
#  |  :SeeAlso: Deterministic, Node, LazyFunction, stoch, dtrm, data, Model, Container
#  |
#  |  Method resolution order:
#  |      Stochastic
#  |      pymc.Node.StochasticBase
#  |      pymc.six.NewBase
#  |      pymc.Node.Variable
#  |      pymc.Node.Node
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, logp, doc, name, parents, random=None, trace=True, value=None, dtype=None, rseed=False, observed=False, cache_depth=2, plot=None, verbose=-1, isdata=None, check_logp=True, logp_partial_gradients=None)
#  |
#  |  gen_lazy_function(self)
#  |      Will be called by Node at instantiation.
#  |
#  |  get_logp(self)
#  |
#  |  get_stoch_value(self)
#  |
#  |  get_value(self)
#  |
#  |  logp_gradient_contribution(self, calculation_set=None)
#  |      Calculates the gradient of the joint log posterior with respect to self.
#  |      Calculation of the log posterior is restricted to the variables in calculation_set.
#  |
#  |  logp_partial_gradient(self, variable, calculation_set=None)
#  |      Calculates the partial gradient of the posterior of self with respect to variable.
#  |      Returns zero if self is not in calculation_set.
#  |
#  |  rand = random(self)
#  |
#  |  random(self)
#  |      Draws a new value for a stoch conditional on its parents
#  |      and returns it.
#  |
#  |      Raises an error if no 'random' argument was passed to __init__.
#  |
#  |  revert(self)
#  |      Sets self's value to self's last value. Bypasses the data cleaning in
#  |      the set_value method.
#  |
#  |  set_logp(self, new_logp)
#  |
#  |  set_value(self, value, force=False)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  coparents
#  |      All the variables whose extended children intersect with self's.
#  |
#  |  isdata
#  |
#  |  logp
#  |      Log-probability or log-density of self's current value
#  |      given values of parents.
#  |
#  |  markov_blanket
#  |      Self's coparents, self's extended parents, self's children and self.
#  |
#  |  mask
#  |      Returns the mask for missing values
#  |
#  |  moral_neighbors
#  |      Self's neighbors in the moral graph: self's Markov blanket with self removed.
#  |
#  |  observed
#  |
#  |  shape
#  |      The shape of the value of self.
#  |
#  |  value
#  |      Self's current value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __array_priority__ = 1000
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pymc.Node.Variable:
#  |
#  |  __abs__(self)
#  |
#  |  __add__(self, other, prefix='')
#  |
#  |  __and__(self, other, prefix='')
#  |
#  |  __call__(self, *args, **kwargs)
#  |
#  |  __complex__(self, op=<type 'complex'>)
#  |      # This function will become the actual method.
#  |
#  |  __div__(self, other, prefix='')
#  |
#  |  __divmod__(self, other, prefix='')
#  |
#  |  __float__(self, op=<type 'float'>)
#  |      # This function will become the actual method.
#  |
#  |  __floordiv__(self, other, prefix='')
#  |
#  |  __ge__(self, other)
#  |      # This function will become the method.
#  |
#  |  __getitem__(self, index)
#  |      # Create __getitem__ method.
#  |
#  |  __gt__(self, other)
#  |      # This function will become the method.
#  |
#  |  __hex__(self, op=<built-in function hex>)
#  |      # This function will become the actual method.
#  |
#  |  __iadd__(self, *args)
#  |
#  |  __iand__(self, *args)
#  |
#  |  __idiv__(self, *args)
#  |
#  |  __ifloordiv__(self, *args)
#  |
#  |  __ilshift__(self, *args)
#  |
#  |  __imod__(self, *args)
#  |
#  |  __imul__(self, *args)
#  |
#  |  __int__(self, op=<type 'int'>)
#  |      # This function will become the actual method.
#  |
#  |  __invert__(self)
#  |
#  |  __ior__(self, *args)
#  |
#  |  __ipow__(self, *args)
#  |
#  |  __irshift__(self, *args)
#  |
#  |  __isub__(self, *args)
#  |
#  |  __iter__(self, op=<built-in function iter>)
#  |      # This function will become the actual method.
#  |
#  |  __itruediv__(self, *args)
#  |
#  |  __ixor__(self, *args)
#  |
#  |  __le__(self, other)
#  |      # This function will become the method.
#  |
#  |  __long__(self, op=<type 'long'>)
#  |      # This function will become the actual method.
#  |
#  |  __lshift__(self, other, prefix='')
#  |
#  |  __lt__(self, other)
#  |      # This function will become the method.
#  |
#  |  __mod__(self, other, prefix='')
#  |
#  |  __mul__(self, other, prefix='')
#  |
#  |  __ne__(self, other)
#  |      # This function will become the method.
#  |
#  |  __neg__(self)
#  |
#  |  __oct__(self, op=<built-in function oct>)
#  |      # This function will become the actual method.
#  |
#  |  __or__(self, other, prefix='')
#  |
#  |  __pow__(self, other, prefix='')
#  |
#  |  __radd__(self, other, prefix='r')
#  |
#  |  __rand__(self, other, prefix='r')
#  |
#  |  __rdiv__(self, other, prefix='r')
#  |
#  |  __rdivmod__(self, other, prefix='r')
#  |
#  |  __rfloordiv__(self, other, prefix='r')
#  |
#  |  __rlshift__(self, other, prefix='r')
#  |
#  |  __rmod__(self, other, prefix='r')
#  |
#  |  __rmul__(self, other, prefix='r')
#  |
#  |  __ror__(self, other, prefix='r')
#  |
#  |  __rpow__(self, other, prefix='r')
#  |
#  |  __rrshift__(self, other, prefix='r')
#  |
#  |  __rshift__(self, other, prefix='')
#  |
#  |  __rsub__(self, other, prefix='r')
#  |
#  |  __rtruediv__(self, other, prefix='r')
#  |
#  |  __rxor__(self, other, prefix='r')
#  |
#  |  __str__(self)
#  |
#  |  __sub__(self, other, prefix='')
#  |
#  |  __truediv__(self, other, prefix='')
#  |
#  |  __xor__(self, other, prefix='')
#  |
#  |  stats(self, alpha=0.05, start=0, batches=100, chain=None, quantiles=(2.5, 25, 50, 75, 97.5))
#  |      Generate posterior statistics for node.
#  |
#  |      :Parameters:
#  |      alpha : float
#  |        The alpha level for generating posterior intervals. Defaults to
#  |        0.05.
#  |
#  |      start : int
#  |        The starting index from which to summarize (each) chain. Defaults
#  |        to zero.
#  |
#  |      batches : int
#  |        Batch size for calculating standard deviation for non-independent
#  |        samples. Defaults to 100.
#  |
#  |      chain : int
#  |        The index for which chain to summarize. Defaults to None (all
#  |        chains).
#  |
#  |      quantiles : tuple or list
#  |        The desired quantiles to be calculated. Defaults to (2.5, 25, 50, 75, 97.5).
#  |
#  |  summary(self, alpha=0.05, start=0, batches=100, chain=None, roundto=3)
#  |      Generate a pretty-printed summary of the node.
#  |
#  |      :Parameters:
#  |      alpha : float
#  |        The alpha level for generating posterior intervals. Defaults to
#  |        0.05.
#  |
#  |      start : int
#  |        The starting index from which to summarize (each) chain. Defaults
#  |        to zero.
#  |
#  |      batches : int
#  |        Batch size for calculating standard deviation for non-independent
#  |        samples. Defaults to 100.
#  |
#  |      chain : int
#  |        The index for which chain to summarize. Defaults to None (all
#  |        chains).
#  |
#  |      roundto : int
#  |        The number of digits to round posterior statistics.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pymc.Node.Variable:
#  |
#  |  plot
#  |      A flag indicating whether self should be plotted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pymc.Node.Node:
#  |
#  |  __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pymc.Node.Node:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  parents
#  |      Self's parents: the variables referred to in self's declaration.

# %%
mcmc = pm.MCMC(model)
mcmc.sample(40000, 10000, 1)

# %%
multi_samples = mcmc.trace('multi')[:]
dirich_samples = mcmc.trace('dirich')[:]
